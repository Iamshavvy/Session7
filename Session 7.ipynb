# %%
import numpy as np
import pandas as pd

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic[["Age", "Name"]]
# Out:
#       Age                                               Name
# 0    22.0                            Braund, Mr. Owen Harris
# 1    38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    26.0                             Heikkinen, Miss. Laina
# 3    35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4    35.0                           Allen, Mr. William Henry
# ..    ...                                                ...
# 886  27.0                              Montvila, Rev. Juozas
# 887  19.0                       Graham, Miss. Margaret Edith
# 888   NaN           Johnston, Miss. Catherine Helen "Carrie"
# 889  26.0                              Behr, Mr. Karl Howell
# 890  32.0                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %%
titanic["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic["Embarked"].describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
titanic["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
titanic["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic["Age"].mean()
# Out:
# 29.69911764705882

# %%
titanic["Age"].median()
# Out:
# 28.0

# %%
titanic["Age"].max()
# Out:
# 80.0

# %%
titanic["Age"].std()
# Out:
# 14.526497332334044

# %%
titanic["Age"].min()
# Out:
# 0.42

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic["Survived"].describe()
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Survived, dtype: float64

# %%
titanic["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic["Sex"] == "female"
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
titanic["Sex"] == "female"
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
titanic[titanic["Sex"] == "female"]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_female = titanic[titanic["Sex"] == "female"]

# %%
titanic_female.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
titanic[titanic["Age"] < 20]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 7              8         0       3        Palsson, Master. Gosta Leonard
# 9             10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3       Sandstrom, Miss. Marguerite Rut
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                  Rice, Master. Eugene
# ..           ...       ...     ...                                   ...
# 855          856         1       3            Aks, Mrs. Sam (Leah Rosen)
# 869          870         1       3       Johnson, Master. Harold Theodor
# 875          876         1       3      Najib, Miss. Adele Kiamie "Jane"
# 877          878         0       3                  Petroff, Mr. Nedelio
# 887          888         1       1          Graham, Miss. Margaret Edith
#
#         Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# ...

# %%
titanic[titanic["Age"] < 20]["Name"]
# Out:
# 7            Palsson, Master. Gosta Leonard
# 9       Nasser, Mrs. Nicholas (Adele Achem)
# 10          Sandstrom, Miss. Marguerite Rut
# 14     Vestrom, Miss. Hulda Amanda Adolfina
# 16                     Rice, Master. Eugene
#                        ...
# 855              Aks, Mrs. Sam (Leah Rosen)
# 869         Johnson, Master. Harold Theodor
# 875        Najib, Miss. Adele Kiamie "Jane"
# 877                    Petroff, Mr. Nedelio
# 887            Graham, Miss. Margaret Edith
# Name: Name, Length: 164, dtype: object

# %%
(titanic["Age"] < 18) & (titanic["Sex"] == "female")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
titanic[(titanic["Age"] < 18) & (titanic["Sex"] == "female")]
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 10            11         1       3
# 14            15         0       3
# 22            23         1       3
# 24            25         0       3
# 39            40         1       3
# 43            44         1       2
# 58            59         1       2
# 68            69         1       3
# 71            72         0       3
# 84            85         1       2
# 111          112         0       3
# 114          115         0       3
# 119          120         0       3
# 147          148         0       3
# 156          157         1       3
# 172          173         1       3
# 184          185         1       3
# 205          206         0       3
# 208          209         1       3
# 233          234         1       3
# 237          238         1       2
# 297          298         0       1
# 307          308         1       1
# 329          330         1       1
# ...

# %%
titanic[(titanic["Age"] > 50) & (titanic["Embarked"] == "S")]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 94            95         0       3
# 124          125         0       1
# 150          151         0       2
# 152          153         0       3
# 170          171         0       1
# 222          223         0       3
# 232          233         0       2
# 249          250         0       2
# 252          253         0       1
# 262          263         0       1
# 268          269         1       1
# 275          276         1       1
# 317          318         0       2
# 326          327         0       3
# 406          407         0       3
# 438          439         0       1
# 449          450         1       1
# 456          457         0       1
# 467          468         0       1
# 483          484         1       3
# 492          493         0       1
# ...

# %%
titanic.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic["Age"].isna().sum()
# Out:
# 177

# %%
titanic.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic = titanic.dropna()

# %%
titanic.shape
# Out:
# (183, 12)

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.dropna(inplace=True)

# %%
titanic.shape
# Out:
# (183, 12)

# %%
titanic.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
titanic.dropna(axis=1, inplace=True)

# %%
titanic.shape
# Out:
# (891, 9)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    male      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                             Heikkinen, Miss. Laina  female      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                           Allen, Mr. William Henry    male      0      0
#
#              Ticket     Fare
# 0         A/5 21171   7.2500
# 1          PC 17599  71.2833
# 2  STON/O2. 3101282   7.9250
# 3            113803  53.1000
# 4            373450   8.0500

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Delete rows where 'Age' is missing
titanic.dropna(subset=["Age"], inplace=True)

# %%
titanic.shape
# Out:
# (714, 12)

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          529
# Embarked         2
# dtype: int64

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
# Delete rows where 'Age' or 'Embarked' is missing
titanic.dropna(subset=["Age", "Embarked"], inplace=True)

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          529
# Embarked         0
# dtype: int64

# %%
titanic.shape
# Out:
# (712, 12)

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
### Count number of columns missing per row

# %%
True + True
# Out:
# 2

# %%
False + False
# Out:
# 0

# %%
titanic["Age"].isna().astype(int) + titanic["Embarked"].isna().astype(int) + titanic["Cabin"].isna().astype(int)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    2
# 889    0
# 890    1
# Length: 891, dtype: int64

# %%
titanic["missing"] = titanic["Age"].isna().astype(int) + titanic["Embarked"].isna().astype(int) + titanic["Cabin"].isna().astype(int)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  missing
# 0      0         A/5 21171   7.2500   NaN        S        1
# 1      0          PC 17599  71.2833   C85        C        0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        1
# 3      0            113803  53.1000  C123        S        0
# ...

# %%
titanic["missing"].unique()
# Out:
# array([1, 0, 2])

# %%
titanic["missing"].value_counts()
# Out:
# 1    550
# 0    183
# 2    158
# Name: missing, dtype: int64

# %%
titanic.dropna(thresh=12, inplace=True)

# %%
titanic.shape
# Out:
# (733, 13)

# %%
titanic["missing"].value_counts()
# Out:
# 1    550
# 0    183
# Name: missing, dtype: int64

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
titanic.dropna(subset=["Age", "Cabin"], thresh=1, inplace=True)

# %%
titanic.shape
# Out:
# (733, 12)

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.dropna(axis=1, thresh=691, inplace=True)

# %%
titanic.shape
# Out:
# (891, 11)

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
titanic["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic["Embarked"].fillna("S")
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
titanic["Embarked"].fillna("S", inplace=True)

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
titanic["Embarked"].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic["Age"].fillna(titanic["Age"].mean(), inplace=True)

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
titanic["Cabin"].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic["Fare"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
titanic.groupby(["Sex"])["Fare"].mean()
# Out:
# Sex
# female    44.479818
# male      25.523893
# Name: Fare, dtype: float64

# %%
titanic.groupby(["Pclass"])["Fare"].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
titanic.groupby(["Pclass", "Sex"])["Fare"].mean()
# Out:
# Pclass  Sex
# 1       female    106.125798
#         male       67.226127
# 2       female     21.970121
#         male       19.741782
# 3       female     16.118810
#         male       12.661633
# Name: Fare, dtype: float64

# %%
titanic.groupby(["Pclass", "Sex"])["Sex"].count()
# Out:
# Pclass  Sex
# 1       female     94
#         male      122
# 2       female     76
#         male      108
# 3       female    144
#         male      347
# Name: Sex, dtype: int64

# %%
titanic["Age"].isna().sum()
# Out:
# 177

# %%
titanic.groupby(["Sex"])["Age"].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
titanic["Age"].mean()
# Out:
# 29.69911764705882

# %%
titanic.groupby(["Sex"])["Age"].transform('mean')
# Out:
# 0      30.726645
# 1      27.915709
# 2      27.915709
# 3      27.915709
# 4      30.726645
#          ...
# 886    30.726645
# 887    27.915709
# 888    27.915709
# 889    30.726645
# 890    30.726645
# Name: Age, Length: 891, dtype: float64

# %%
titanic["Sex"]
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
titanic["Age"].fillna(titanic.groupby(["Sex"])["Age"].transform('mean'),
                     inplace=True)

# %%
titanic["Age"]
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    27.915709
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
titanic.loc[:10,"Name"]
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# Name: Name, dtype: object

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.loc[:5, "Ticket":]
# Out:
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q

# %%
titanic.loc[:5,["Name", "Age"]]
# Out:
#                                                 Name        Age
# 0                            Braund, Mr. Owen Harris  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.000000
# 2                             Heikkinen, Miss. Laina  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.000000
# 4                           Allen, Mr. William Henry  35.000000
# 5                                   Moran, Mr. James  30.726645

# %%
titanic.loc[[1,2,5], ["Name", "Age"]]
# Out:
#                                                 Name        Age
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.000000
# 2                             Heikkinen, Miss. Laina  26.000000
# 5                                   Moran, Mr. James  30.726645

# %%
titanic.iloc[:5, :2]
# Out:
#    PassengerId  Survived
# 0            1         0
# 1            2         1
# 2            3         1
# 3            4         1
# 4            5         0

# %%
titanic.iloc[:5, 2:]
# Out:
#    Pclass                                               Name     Sex   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171   7.2500   NaN        S
# 1      1      0          PC 17599  71.2833   C85        C
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      1      0            113803  53.1000  C123        S
# 4      0      0            373450   8.0500   NaN        S

# %%
titanic.iloc[:,25]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/0x/8qbylcs945qcwxhy42nzt0340000gn/T/ipykernel_2006/2492336997.py in <module>
# ----> 1 titanic.iloc[:,25]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
#    1505
# -> 1506         self._has_valid_tuple(tup)
#    1507         with suppress(IndexingError):
#    1508             return self._getitem_lowerdim(tup)
#
# ...

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic["Age"].astype(int)
# Out:
# 0      22
# 1      38
# 2      26
# 3      35
# 4      35
#        ..
# 886    27
# 887    19
# 888    27
# 889    26
# 890    32
# Name: Age, Length: 891, dtype: int64

# %%
titanic["Age"] = titanic["Age"].astype(int)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 83.7+ KB

# %%
titanic["Minor"] = "No"

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked Minor
# 0      0         A/5 21171   7.2500   NaN        S    No
# 1      0          PC 17599  71.2833   C85        C    No
# 2      0  STON/O2. 3101282   7.9250   NaN        S    No
# 3      0            113803  53.1000  C123        S    No
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  Minor        891 non-null    object
# dtypes: float64(1), int64(6), object(6)
# memory usage: 90.6+ KB

# %%
titanic["Minor"].unique()
# Out:
# array(['No'], dtype=object)

# %%
titanic["Minor"].value_counts()
# Out:
# No    891
# Name: Minor, dtype: int64

# %%
# Conditional Replacement

# %%
titanic.loc[titanic["Age"]<=18, "Minor"] = "Yes"

# %%
titanic["Minor"].value_counts()
# Out:
# No     752
# Yes    139
# Name: Minor, dtype: int64

# %%
titanic_female.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
titanic_female.loc[:5,"Name"]
# Out:
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Name: Name, dtype: object

# %%
titanic_female.reset_index()
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        1            2         1       1
# 1        2            3         1       3
# 2        3            4         1       1
# 3        8            9         1       3
# 4        9           10         1       2
# ..     ...          ...       ...     ...
# 309    880          881         1       2
# 310    882          883         0       3
# 311    885          886         0       3
# 312    887          888         1       1
# 313    888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1                               Heikkinen, Miss. Laina  female  26.0      0
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 3    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ...

# %%
titanic_female.reset_index(drop=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              2         1       1
# 1              3         1       3
# 2              4         1       1
# 3              9         1       3
# 4             10         1       2
# ..           ...       ...     ...
# 309          881         1       2
# 310          883         0       3
# 311          886         0       3
# 312          888         1       1
# 313          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1                               Heikkinen, Miss. Laina  female  26.0      0
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 3    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 4                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_female.reset_index(drop=True, inplace=True)

# %%
titanic_female.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            2         1       1
# 1            3         1       3
# 2            4         1       1
# 3            9         1       3
# 4           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1                             Heikkinen, Miss. Laina  female  26.0      0
# 2       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 4                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0          PC 17599  71.2833   C85        C
# 1      0  STON/O2. 3101282   7.9250   NaN        S
# 2      0            113803  53.1000  C123        S
# 3      2            347742  11.1333   NaN        S
# 4      0            237736  30.0708   NaN        C

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Minor'],
#       dtype='object')

# %%
titanic.columns = ['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
       'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Minor']

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked Minor
# 0      0         A/5 21171   7.2500   NaN        S    No
# 1      0          PC 17599  71.2833   C85        C    No
# 2      0  STON/O2. 3101282   7.9250   NaN        S    No
# 3      0            113803  53.1000  C123        S    No
# ...

# %%
titanic.rename({"PassengerId": "PID", "Pclass": "Class"},
              axis=1)
# Out:
#      PID  Survived  Class                                               Name  \
# 0      1         0      3                            Braund, Mr. Owen Harris
# 1      2         1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3         1      3                             Heikkinen, Miss. Laina
# 3      4         1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5         0      3                           Allen, Mr. William Henry
# ..   ...       ...    ...                                                ...
# 886  887         0      2                              Montvila, Rev. Juozas
# 887  888         1      1                       Graham, Miss. Margaret Edith
# 888  889         0      3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890         1      1                              Behr, Mr. Karl Howell
# 890  891         0      3                                Dooley, Mr. Patrick
#
# ...

# %%
titanic.rename({"PassengerId": "PID", "Pclass": "Class"},
              axis=1, inplace=True)

# %%
titanic.head()
# Out:
#    PID  Survived  Class                                               Name  \
# 0    1         0      3                            Braund, Mr. Owen Harris
# 1    2         1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    3         1      3                             Heikkinen, Miss. Laina
# 3    4         1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4    5         0      3                           Allen, Mr. William Henry
#
#    Gender  Age  SibSp  Parch            Ticket     Fare Cabin Embarked Minor
# 0    male   22      1      0         A/5 21171   7.2500   NaN        S    No
# 1  female   38      1      0          PC 17599  71.2833   C85        C    No
# 2  female   26      0      0  STON/O2. 3101282   7.9250   NaN        S    No
# 3  female   35      1      0            113803  53.1000  C123        S    No
# 4    male   35      0      0            373450   8.0500   NaN        S    No

# %%
titanic.rename({1:1001})
# Out:
#       PID  Survived  Class                                               Name  \
# 0       1         0      3                            Braund, Mr. Owen Harris
# 1001    2         1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3         1      3                             Heikkinen, Miss. Laina
# 3       4         1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       5         0      3                           Allen, Mr. William Henry
# ...   ...       ...    ...                                                ...
# 886   887         0      2                              Montvila, Rev. Juozas
# 887   888         1      1                       Graham, Miss. Margaret Edith
# 888   889         0      3           Johnston, Miss. Catherine Helen "Carrie"
# 889   890         1      1                              Behr, Mr. Karl Howell
# 890   891         0      3                                Dooley, Mr. Patrick
#
# ...

# %%
titanic.drop(["Cabin"], axis=1)
# Out:
#      PID  Survived  Class                                               Name  \
# 0      1         0      3                            Braund, Mr. Owen Harris
# 1      2         1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3         1      3                             Heikkinen, Miss. Laina
# 3      4         1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5         0      3                           Allen, Mr. William Henry
# ..   ...       ...    ...                                                ...
# 886  887         0      2                              Montvila, Rev. Juozas
# 887  888         1      1                       Graham, Miss. Margaret Edith
# 888  889         0      3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890         1      1                              Behr, Mr. Karl Howell
# 890  891         0      3                                Dooley, Mr. Patrick
#
# ...

# %%
titanic.drop([2,5], axis=0)
# Out:
#      PID  Survived  Class                                               Name  \
# 0      1         0      3                            Braund, Mr. Owen Harris
# 1      2         1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3      4         1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5         0      3                           Allen, Mr. William Henry
# 6      7         0      1                            McCarthy, Mr. Timothy J
# ..   ...       ...    ...                                                ...
# 886  887         0      2                              Montvila, Rev. Juozas
# 887  888         1      1                       Graham, Miss. Margaret Edith
# 888  889         0      3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890         1      1                              Behr, Mr. Karl Howell
# 890  891         0      3                                Dooley, Mr. Patrick
#
# ...

# %%
titanic.shape
# Out:
# (891, 13)

# %%
titanic.index = range(1000,1891)

# %%
titanic.head()
# Out:
#       PID  Survived  Class                                               Name  \
# 1000    1         0      3                            Braund, Mr. Owen Harris
# 1001    2         1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 1002    3         1      3                             Heikkinen, Miss. Laina
# 1003    4         1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 1004    5         0      3                           Allen, Mr. William Henry
#
#       Gender  Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 1000    male   22      1      0         A/5 21171   7.2500   NaN        S
# 1001  female   38      1      0          PC 17599  71.2833   C85        C
# 1002  female   26      0      0  STON/O2. 3101282   7.9250   NaN        S
# 1003  female   35      1      0            113803  53.1000  C123        S
# 1004    male   35      0      0            373450   8.0500   NaN        S
#
#      Minor
# 1000    No
# 1001    No
# 1002    No
# ...

# %%
titanic.tail()
# Out:
#       PID  Survived  Class                                      Name  Gender  \
# 1886  887         0      2                     Montvila, Rev. Juozas    male
# 1887  888         1      1              Graham, Miss. Margaret Edith  female
# 1888  889         0      3  Johnston, Miss. Catherine Helen "Carrie"  female
# 1889  890         1      1                     Behr, Mr. Karl Howell    male
# 1890  891         0      3                       Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch      Ticket   Fare Cabin Embarked Minor
# 1886   27      0      0      211536  13.00   NaN        S    No
# 1887   19      0      0      112053  30.00   B42        S    No
# 1888   27      1      2  W./C. 6607  23.45   NaN        S    No
# 1889   26      0      0      111369  30.00  C148        C    No
# 1890   32      0      0      370376   7.75   NaN        Q    No

# %%
titanic["Name"]
# Out:
# 1000                              Braund, Mr. Owen Harris
# 1001    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 1002                               Heikkinen, Miss. Laina
# 1003         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 1004                             Allen, Mr. William Henry
#                               ...
# 1886                                Montvila, Rev. Juozas
# 1887                         Graham, Miss. Margaret Edith
# 1888             Johnston, Miss. Catherine Helen "Carrie"
# 1889                                Behr, Mr. Karl Howell
# 1890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
titanic["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
titanic["Name"][0]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
titanic["Name"][0].split(",")
# Out:
# ['Braund', ' Mr. Owen Harris']

# %%
titanic["Name"][0].split(",")[0]
# Out:
# 'Braund'

# %%
def extract_ln(name):
    return name.split(",")[0]

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic["Name"].apply(extract_ln)
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: Name, Length: 891, dtype: object

# %%
titanic["LastName"] = titanic["Name"].apply(extract_ln)

# %%
titanic["Name"].apply(lambda x: x.split(",")[0])
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: Name, Length: 891, dtype: object

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   LastName
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# ...

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'LastName'],
#       dtype='object')

# %%
titanic[['PassengerId', 'Survived', 'Pclass', 'Name', 'LastName','Sex', 'Age', 'SibSp',
       'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   LastName     Sex  \
# 0                              Braund, Mr. Owen Harris     Braund    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    Cumings  female
# 2                               Heikkinen, Miss. Laina  Heikkinen  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   Futrelle  female
# 4                             Allen, Mr. William Henry      Allen    male
# ..                                                 ...        ...     ...
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   LastName
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# ...

# %%
def create_gender(row):
    if row["Age"] < 19:
        if row["Sex"] == "female":
            return "girl"
        else:
            return "boy"
    else:
        return row["Sex"]

# %%
titanic.apply(create_gender, axis=1)
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Length: 891, dtype: object

# %%
titanic["Gender"] = titanic.apply(create_gender, axis=1)

# %%
titanic["Gender"].value_counts()
# Out:
# male      506
# female    246
# boy        71
# girl       68
# Name: Gender, dtype: int64

# %%
df1 = pd.DataFrame({"ID": [1,2,3],
                   "Name": ["Priya", "Kumar", "Mahesh"]})
df2 = pd.DataFrame({"ID": [1,2,4],
                   "Dept": ["IT", "HR", "IT"]})

# %%
df1
# Out:
#    ID    Name
# 0   1   Priya
# 1   2   Kumar
# 2   3  Mahesh

# %%
df2
# Out:
#    ID Dept
# 0   1   IT
# 1   2   HR
# 2   4   IT

# %%
df1.merge(df2, on = ["ID"], how = "left")
# Out:
#    ID    Name Dept
# 0   1   Priya   IT
# 1   2   Kumar   HR
# 2   3  Mahesh  NaN

# %%
df1.merge(df2, on = ["ID"], how = "right")
# Out:
#    ID   Name Dept
# 0   1  Priya   IT
# 1   2  Kumar   HR
# 2   4    NaN   IT

# %%
df1.merge(df2, on = ["ID"], how = "inner")
# Out:
#    ID   Name Dept
# 0   1  Priya   IT
# 1   2  Kumar   HR

# %%
df1.merge(df2, on = ["ID"], how = "outer")
# Out:
#    ID    Name Dept
# 0   1   Priya   IT
# 1   2   Kumar   HR
# 2   3  Mahesh  NaN
# 3   4     NaN   IT

# %%
df1
# Out:
#    ID    Name
# 0   1   Priya
# 1   2   Kumar
# 2   3  Mahesh

# %%
df1.rename({"ID": "id"}, axis=1, inplace=True)

# %%
df1
# Out:
#    id    Name
# 0   1   Priya
# 1   2   Kumar
# 2   3  Mahesh

# %%
df1.merge(df2, on="ID", how="left")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/0x/8qbylcs945qcwxhy42nzt0340000gn/T/ipykernel_2006/1287693949.py in <module>
# ----> 1 df1.merge(df2, on="ID", how="left")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9188         from pandas.core.reshape.merge import merge
#    9189
# -> 9190         return merge(
#    9191             self,
#    9192             right,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# ...

# %%
df1.merge(df2, left_on="id", right_on="ID", how="left")
# Out:
#    id    Name   ID Dept
# 0   1   Priya  1.0   IT
# 1   2   Kumar  2.0   HR
# 2   3  Mahesh  NaN  NaN

# %%
df3 = pd.DataFrame({"FN": ["Priya", "Ajay", "Ajay"],
                   "LN": ["Singh", "Kumar", "Singh"],
                   "Dept": ["IT", "HR", "IT"]})
df4 = pd.DataFrame({"FN": ["Priya", "Ajay", "Ajay"],
                   "LN": ["Singh", "Kumar", "Singh"],
                   "Desg": ["Manager", "Officer", "Manager"]})

# %%
df3
# Out:
#       FN     LN Dept
# 0  Priya  Singh   IT
# 1   Ajay  Kumar   HR
# 2   Ajay  Singh   IT

# %%
df4
# Out:
#       FN     LN     Desg
# 0  Priya  Singh  Manager
# 1   Ajay  Kumar  Officer
# 2   Ajay  Singh  Manager

# %%
df3.merge(df4, on = ["FN", "LN"], how="left")
# Out:
#       FN     LN Dept     Desg
# 0  Priya  Singh   IT  Manager
# 1   Ajay  Kumar   HR  Officer
# 2   Ajay  Singh   IT  Manager

# %%
df3.rename({"FN":"fn"}, axis=1, inplace=True)

# %%
df3
# Out:
#       fn     LN Dept
# 0  Priya  Singh   IT
# 1   Ajay  Kumar   HR
# 2   Ajay  Singh   IT

# %%
df3.merge(df4, left_on = ["fn", "LN"],
         right_on = ["FN", "LN"], how="left")
# Out:
#       fn     LN Dept     FN     Desg
# 0  Priya  Singh   IT  Priya  Manager
# 1   Ajay  Kumar   HR   Ajay  Officer
# 2   Ajay  Singh   IT   Ajay  Manager

# %%
df5 = pd.DataFrame({"Name": ["Priya", "Kumar", "Anand"],
                   "Dept": ["IT", "HR", "IT"]},
                  index=[1,2,4])
df6 = pd.DataFrame({"name": ["Priya", "Kumar", "Anand"],
                   "Desg": ["Mgr", "Officer", "Mgr"]},
                  index=[1,2,3])

# %%
df5
# Out:
#     Name Dept
# 1  Priya   IT
# 2  Kumar   HR
# 4  Anand   IT

# %%
df6
# Out:
#     name     Desg
# 1  Priya      Mgr
# 2  Kumar  Officer
# 3  Anand      Mgr

# %%
df5.join(df6, how="outer")
# Out:
#     Name Dept   name     Desg
# 1  Priya   IT  Priya      Mgr
# 2  Kumar   HR  Kumar  Officer
# 3    NaN  NaN  Anand      Mgr
# 4  Anand   IT    NaN      NaN

# %%
df1
# Out:
#    id    Name
# 0   1   Priya
# 1   2   Kumar
# 2   3  Mahesh

# %%
df2
# Out:
#    ID Dept
# 0   1   IT
# 1   2   HR
# 2   4   IT

# %%
df1.set_index("id")
# Out:
#       Name
# id
# 1    Priya
# 2    Kumar
# 3   Mahesh

# %%
df2.set_index("ID")
# Out:
#    Dept
# ID
# 1    IT
# 2    HR
# 4    IT

# %%
df1.set_index("id").join(df2.set_index("ID"), how="outer")
# Out:
#      Name Dept
# 1   Priya   IT
# 2   Kumar   HR
# 3  Mahesh  NaN
# 4     NaN   IT
